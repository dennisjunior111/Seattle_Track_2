# %%
# import packages
import pandas as pd
from geopy.distance import great_circle
import datetime
import matplotlib.pyplot as plt
from datetime import timedelta

# %%
# Read in .csv
df = pd.read_csv('AIS_2017_01_Zone11.csv')

# %%
# Make a copy of the dataframe
df_orgin = df

# %%
#Convert time type
df['BaseDateTime'] = pd.to_datetime(df['BaseDateTime'])
df.head(20)
# Out:
#          MMSI        BaseDateTime       LAT        LON   SOG    COG  Heading  \
# 0   367067810 2017-01-01 00:00:06  33.74757 -118.21565   0.0  181.7    511.0
# 1   367001740 2017-01-01 00:00:07  33.34445 -118.32208   0.1   81.0    159.0
# 2   236000990 2017-01-01 00:00:16  32.70992 -117.23312   0.0  203.1    511.0
# 3   538004441 2017-01-01 00:00:36  33.74393 -118.20837   0.0  -99.6    310.0
# 4   367452560 2017-01-01 00:01:10  32.76216 -117.23657   0.0  -49.6    511.0
# 5   319018800 2017-01-01 00:01:17  32.70976 -117.23350   0.0  -69.7    344.0
# 6   367599960 2017-01-01 00:01:24  33.72064 -118.27863   0.0  -49.6    511.0
# 7   367371520 2017-01-01 00:01:33  33.61821 -117.92194   0.0   20.3    511.0
# 8   367506730 2017-01-01 00:01:40  33.97614 -118.44953   0.0   16.5    511.0
# 9   338139535 2017-01-01 00:01:47  33.71937 -118.05758   0.1  190.7    511.0
# 10  367452560 2017-01-01 00:00:01  32.76217 -117.23659   0.0  -49.6    511.0
# ...

# %%
df.loc[1,"MMSI":'LON']
# Out:
# MMSI                      367001740
# BaseDateTime    2017-01-01 00:00:07
# LAT                         33.3445
# LON                        -118.322
# Name: 1, dtype: object

# %%
t = df['new_time'][1]
t+timedelta(seconds=60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-604069e647c7> in <module>()
#       1 t = df['new_time'][1]
# ----> 2 t+timedelta(seconds=60)
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'datetime.timedelta'

# %%
# Start trying to find colregs

# %%
df_sort = df.sort_values(by=['MMSI','LAT','LON','BaseDateTime'])

# %%
df_sort.head(10)
# Out:
#             MMSI        BaseDateTime       LAT        LON   SOG    COG  \
# 740498   1193046 2017-01-03 16:53:25  32.67137 -117.12294   6.5   73.0
# 746566   1193046 2017-01-03 16:58:43  32.67252 -117.11967   0.0    0.0
# 738850   1193046 2017-01-03 17:03:03  32.67568 -117.12825   8.6  -79.4
# 742139   1193046 2017-01-03 16:49:15  32.67631 -117.12876   6.6  147.8
# 735578   1193046 2017-01-03 16:48:05  32.67809 -117.13024   6.9  142.5
# 734921   1193046 2017-01-03 16:47:04  32.67966 -117.13169   6.9  145.4
# 742212   1193046 2017-01-03 17:05:14  32.67976 -117.13193   8.5  -90.6
# 1187263  1193046 2017-01-03 16:44:54  32.68299 -117.13337   5.7 -187.2
# 733845   1193046 2017-01-03 16:36:24  32.68382 -117.13895  10.0  121.8
# 717066   1193046 2017-01-03 15:18:44  32.68412 -117.13801   9.4 -138.2
#
#          Heading VesselName           IMO CallSign  VesselType  \
# 740498     511.0  NAUTICAST  IMO303174162   D11233        50.0
# ...

# %%
df['new_date'] = [d.date() for d in df['BaseDateTime']]
df['new_time'] = [d.time() for d in df['BaseDateTime']]

# %%
df.head()
# Out:
#         MMSI        BaseDateTime       LAT        LON  SOG    COG  Heading  \
# 0  367067810 2017-01-01 00:00:06  33.74757 -118.21565  0.0  181.7    511.0
# 1  367001740 2017-01-01 00:00:07  33.34445 -118.32208  0.1   81.0    159.0
# 2  236000990 2017-01-01 00:00:16  32.70992 -117.23312  0.0  203.1    511.0
# 3  538004441 2017-01-01 00:00:36  33.74393 -118.20837  0.0  -99.6    310.0
# 4  367452560 2017-01-01 00:01:10  32.76216 -117.23657  0.0  -49.6    511.0
#
#   VesselName  IMO CallSign  VesselType                  Status  Length  Width  \
# 0        NaN  NaN      NaN         NaN               undefined     NaN    NaN
# 1        NaN  NaN      NaN         NaN  under way using engine     NaN    NaN
# 2        NaN  NaN      NaN         NaN                     NaN     NaN    NaN
# 3        NaN  NaN      NaN         NaN                  moored     NaN    NaN
# 4        NaN  NaN      NaN         NaN  under way using engine     NaN    NaN
#
#    Draft  Cargo    new_date  new_time
# ...

# %%
df_sort = df.sort_values(by=['MMSI','LAT','LON','new_date','new_time'])

# %%
for i in 10000:
    roi = df.loc[i,"MMSI":'LON']
    for j in 10000:
        lat = df.loc[j,'LAT']
        lon = df.loc[j,'LON']
        mmsi = df.loc[j,'MMSI']
        date = df.loc[j,'new_date']
        time = df.loc[j,'new_time']
        if roi['new_date'] == df.loc[j,'LAT']&& roi['LAT'] == df.loc[j,'LAT']&& roi['LAT'] == df.loc[j,'LAT']
