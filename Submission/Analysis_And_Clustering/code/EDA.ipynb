# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv('AIS_ASCII_by_UTM_Month/2017/AIS_2017_01_Zone01.csv')

# %%
raw.head()
# Out:
#         MMSI         BaseDateTime       LAT        LON   SOG    COG  Heading  \
# 0  366940480  2017-01-04T11:39:36  52.48730 -174.02316  10.0 -140.7    267.0
# 1  366940480  2017-01-04T11:40:45  52.48718 -174.02835  10.0 -141.6    266.0
# 2  366940480  2017-01-04T11:42:26  52.48705 -174.03608  10.0 -142.3    267.0
# 3  366940480  2017-01-04T13:51:07  52.41575 -174.60041   9.1 -154.0    251.0
# 4  366940480  2017-01-04T13:55:17  52.41311 -174.61718   9.1 -157.3    251.0
#
#    VesselName         IMO CallSign  VesselType     Status  Length  Width  \
# 0  EARLY DAWN  IMO7821130  WDB7319      1001.0  undefined   32.95   8.82
# 1  EARLY DAWN  IMO7821130  WDB7319      1001.0  undefined   32.95   8.82
# 2  EARLY DAWN  IMO7821130  WDB7319      1001.0  undefined   32.95   8.82
# 3  EARLY DAWN  IMO7821130  WDB7319      1001.0  undefined   32.95   8.82
# 4  EARLY DAWN  IMO7821130  WDB7319      1001.0  undefined   32.95   8.82
#
#    Draft  Cargo
# 0    4.0   31.0
# 1    4.0   31.0
# ...

# %%
single_ship_id = 352844000

# %%
single_ship_records = raw[raw.MMSI == single_ship_id].sort_values(by="BaseDateTime")

# %%
single_ship_records.tail()
# Out:
#             MMSI         BaseDateTime       LAT        LON  SOG    COG  \
# 9565   352844000  2017-01-31T23:45:32  51.89777 -176.59310  1.1 -104.8
# 10081  352844000  2017-01-31T23:48:32  51.89763 -176.59387  0.7  200.3
# 10223  352844000  2017-01-31T23:51:33  51.89753 -176.59389  1.0   40.3
# 9568   352844000  2017-01-31T23:54:33  51.89797 -176.59368  0.3 -115.1
# 10220  352844000  2017-01-31T23:57:32  51.89758 -176.59405  0.3  204.1
#
#        Heading VesselName         IMO CallSign  VesselType     Status  Length  \
# 9565     137.0      JACHA  IMO8512920    3EFC4      1004.0  at anchor   92.21
# 10081    133.0      JACHA  IMO8512920    3EFC4      1004.0  at anchor   92.21
# 10223     91.0      JACHA  IMO8512920    3EFC4      1004.0  at anchor   92.21
# 9568     145.0      JACHA  IMO8512920    3EFC4      1004.0  at anchor   92.21
# 10220    115.0      JACHA  IMO8512920    3EFC4      1004.0  at anchor   92.21
#
#        Width  Draft  Cargo
# 9565   16.21    6.6   70.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.pointplot(data=single_ship_records, x='BaseDateTime', y="LAT", hue="Status")

# %%
raw.sort_values(by="BaseDateTime")
# Out:
#             MMSI         BaseDateTime       LAT        LON   SOG    COG  \
# 963    370633000  2017-01-01T23:58:14  53.26142 -177.15349  10.7   83.1
# 3080   370633000  2017-01-02T00:03:01  53.26260 -177.12988  10.5   87.1
# 3081   370633000  2017-01-02T00:27:48  53.26243 -177.00642  10.7   86.1
# 3107   370633000  2017-01-02T00:29:22  53.26291 -176.99857  11.1   81.7
# 3108   370633000  2017-01-02T00:30:43  53.26315 -176.99183  10.7   88.8
# 964    370633000  2017-01-02T00:32:08  53.26314 -176.98460  11.1   90.4
# 1016   370633000  2017-01-02T00:35:36  53.26425 -176.96693  10.9   84.6
# 3109   370633000  2017-01-02T00:37:45  53.26480 -176.95603  10.8   83.7
# 3099   370633000  2017-01-02T00:41:55  53.26509 -176.93515  11.0   85.1
# 1017   370633000  2017-01-02T00:43:49  53.26499 -176.92577  10.8   87.2
# 3110   370633000  2017-01-02T00:45:02  53.26528 -176.91960  11.2   80.3
# 3111   370633000  2017-01-02T00:48:23  53.26598 -176.90237  11.2   83.7
# ...
