# %%
# filter array for item where key-value pairs match

# %%
import pandas as pd

# %%
raw = pd.read_csv('../data/AIS_ASCII_by_UTM_Month/2017/AIS_2017_01_Zone01.csv')

# %%
import simpleInteractionFinder as sif

# %%
results = sif.predictInteractions(raw, sif.haversineDistance, 300)
# Out:
# 54539
# {'time': '2017-01-04T20:44:15', 'distance': 231.90485824983975, 'shipB': MMSI                      366940480
# BaseDateTime    2017-01-04T20:44:15
# LAT                          52.114
# LON                        -176.353
# SOG                             9.3
# COG                          -164.9
# Heading                         244
# VesselName               EARLY DAWN
# IMO                      IMO7821130
# CallSign                    WDB7319
# VesselType                     1001
# Status                    undefined
# Length                        32.95
# Width                          8.82
# Draft                             4
# Cargo                            31
# Name: 281, dtype: object, 'shipA': MMSI                         353073000
# BaseDateTime       2017-01-04T20:43:11
# LAT                            54.1648
# LON                           -176.981
# SOG                               12.5
# COG                             -141.6
# ...

# %%
ships = {
    "shipABC": {
        "shipDEF": {
            "distance": 2miles,
            "timeLastReported": 8:05AM
        },
        "shipXYZ": {
            distance: 3.1miles,
            timeLastReported: 7:58PM
        }
    },
    "shipDEF": {
        "shipABC": {
            distance: 2miles,
            timeLastReported: 8:02AM
        },
        "shipXYZ": {
            distance: 4.1miles,
            timeLastReported: 7:58AM
        }
    },
    "shipXYZ": {
        "shipABC": {
            distance: 3.1miles,
            timeLastReported: 7:54PM
        },
        "shipDEF": {
            distance: 4.1miles,
            timeLastReported: 8:05AM
        }
    }
}
